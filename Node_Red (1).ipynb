# %%
import numpy as np
import pandas as pd
dataset=pd.read_csv("acquisitions.csv")

# %%
dataset
# Out:
#     AcquisitionID AcquisitionMonth  AcquisitionMonthDate  AcquisitionYear  \
# 0           ACQ99         November                  11.0             2015
# 1           ACQ98         November                  11.0             2015
# 2           ACQ97         December                   8.0             2015
# 3           ACQ96         December                  18.0             2015
# 4           ACQ95         December                  21.0             2015
# 5           ACQ94          January                   7.0             2016
# 6           ACQ93          January                  15.0             2016
# 7           ACQ92          January                  19.0             2016
# 8          ACQ915             July                  30.0             1987
# 9          ACQ914            March                   2.0             1988
# 10         ACQ913             June                   7.0             1988
# 11         ACQ912             June                  27.0             1988
# ...

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
dataset.head()
# Out:
#   AcquisitionID AcquisitionMonth  AcquisitionMonthDate  AcquisitionYear  \
# 0         ACQ99         November                  11.0             2015
# 1         ACQ98         November                  11.0             2015
# 2         ACQ97         December                   8.0             2015
# 3         ACQ96         December                  18.0             2015
# 4         ACQ95         December                  21.0             2015
#
#        Company                      Business Country  Value (USD)  \
# 0        bebop                Cloud software     USA  380000000.0
# 1     Fly Labs                 Video editing     USA          NaN
# 2    Clearleap  Cloud-based video management     USA          NaN
# 3   Metanautix            Big Data Analytics     USA          NaN
# 4  Talko, Inc.         Mobile communications     USA          NaN
#
#         Derived products ParentCompany
# 0  Google Cloud Platform        Google
# 1          Google Photos        Google
# ...

# %%
dataset.shape
# Out:
# (916, 10)

# %%
dataset.isnull().sum()
# Out:
# AcquisitionID             0
# AcquisitionMonth          6
# AcquisitionMonthDate     33
# AcquisitionYear           0
# Company                   0
# Business                  0
# Country                  46
# Value (USD)             671
# Derived products        515
# ParentCompany             0
# dtype: int64

# %%
data1=dataset.iloc[:,[0,1,3,5,6,7,9]]

# %%
data1
# Out:
#     AcquisitionID AcquisitionMonth  AcquisitionYear  \
# 0           ACQ99         November             2015
# 1           ACQ98         November             2015
# 2           ACQ97         December             2015
# 3           ACQ96         December             2015
# 4           ACQ95         December             2015
# 5           ACQ94          January             2016
# 6           ACQ93          January             2016
# 7           ACQ92          January             2016
# 8          ACQ915             July             1987
# 9          ACQ914            March             1988
# 10         ACQ913             June             1988
# 11         ACQ912             June             1988
# 12         ACQ911             July             1988
# 13         ACQ910          January             1989
# 14          ACQ91          January             2016
# 15         ACQ909            March             1991
# 16         ACQ908             June             1992
# ...

# %%
data1.dropna(subset=['Value (USD)'], inplace = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data1
# Out:
#     AcquisitionID AcquisitionMonth  AcquisitionYear  \
# 0           ACQ99         November             2015
# 8          ACQ915             July             1987
# 28         ACQ898          January             1996
# 32         ACQ894            April             1996
# 36         ACQ890         February             1997
# 38         ACQ889         February             1997
# 40         ACQ887            April             1997
# 45         ACQ882        September             1997
# 46         ACQ881        September             1997
# 47         ACQ880          October             1997
# 49         ACQ879         December             1997
# 52         ACQ876            April             1998
# 55         ACQ873             June             1998
# 56         ACQ872             July             1998
# 58         ACQ870          October             1998
# 60         ACQ869         November             1998
# 61         ACQ868         December             1998
# ...

# %%
data1.Country.fillna('USA',inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
data1
# Out:
#     AcquisitionID AcquisitionMonth  AcquisitionYear  \
# 0           ACQ99         November             2015
# 8          ACQ915             July             1987
# 28         ACQ898          January             1996
# 32         ACQ894            April             1996
# 36         ACQ890         February             1997
# 38         ACQ889         February             1997
# 40         ACQ887            April             1997
# 45         ACQ882        September             1997
# 46         ACQ881        September             1997
# 47         ACQ880          October             1997
# 49         ACQ879         December             1997
# 52         ACQ876            April             1998
# 55         ACQ873             June             1998
# 56         ACQ872             July             1998
# 58         ACQ870          October             1998
# 60         ACQ869         November             1998
# 61         ACQ868         December             1998
# ...

# %%
x=data1.iloc[:,:6]

# %%
x
# Out:
#     AcquisitionID AcquisitionMonth  AcquisitionYear  \
# 0           ACQ99         November             2015
# 8          ACQ915             July             1987
# 28         ACQ898          January             1996
# 32         ACQ894            April             1996
# 36         ACQ890         February             1997
# 38         ACQ889         February             1997
# 40         ACQ887            April             1997
# 45         ACQ882        September             1997
# 46         ACQ881        September             1997
# 47         ACQ880          October             1997
# 49         ACQ879         December             1997
# 52         ACQ876            April             1998
# 55         ACQ873             June             1998
# 56         ACQ872             July             1998
# 58         ACQ870          October             1998
# 60         ACQ869         November             1998
# 61         ACQ868         December             1998
# ...

# %%
y=data1.iloc[:,-1:]

# %%
y
# Out:
#     ParentCompany
# 0          Google
# 8       Microsoft
# 28      Microsoft
# 32      Microsoft
# 36      Microsoft
# 38          Apple
# 40      Microsoft
# 45          Yahoo
# 46          Apple
# 47          Yahoo
# 49      Microsoft
# 52      Microsoft
# 55          Yahoo
# 56          Yahoo
# 58          Yahoo
# 60      Microsoft
# 61          Yahoo
# 62          Apple
# 66          Yahoo
# 69          Yahoo
# 70      Microsoft
# 71          Yahoo
# 72          Yahoo
# 75      Microsoft
# 76      Microsoft
# 82          Apple
# 83      Microsoft
# 86      Microsoft
# 90      Microsoft
# 93          Yahoo
# ..            ...
# 745        Google
# 752      Facebook
# 758     Microsoft
# 759      Facebook
# 760      Facebook
# 766       Twitter
# 781       Twitter
# 782       Twitter
# 784        Google
# 789        Google
# 793         Apple
# 799         Yahoo
# 806         Apple
# 814        Google
# 822         Yahoo
# 825         Apple
# 830     Microsoft
# 831         Yahoo
# ...

# %%
x.shape
# Out:
# (245, 6)

# %%
y.shape
# Out:
# (245, 1)

# %%
from sklearn.preprocessing import LabelEncoder
le0 = LabelEncoder()
x.iloc[:,0] = le0.fit_transform(x.iloc[:,0])

# %% [raw]
# class MultiColumnLabelEncoder:
#     def __init__(self,columns = None):
#         self.columns = columns # array of column names to encode
#
#     def fit(self,X,y=None):
#         return self # not relevant here
#
#     def transform(self,X):
#         '''
#         Transforms columns of X specified in self.columns using
#         LabelEncoder(). If no columns specified, transforms all
#         columns in X.
#         '''
#         output = X.copy()
#         if self.columns is not None:
#             for col in self.columns:
#                 output[col] = LabelEncoder().fit_transform(output[col])
#         else:
#             for colname,col in output.iteritems():
#                 output[colname] = LabelEncoder().fit_transform(col)
#         return output
#
#     def fit_transform(self,X,y=None):
#         return self.fit(X,y).transform(X)

# %% [raw]
# encoding_pipeline = Pipeline([('encoding',MultiColumnLabelEncoder(columns=['fruit','color']))])
# encoding_pipeline.fit_transform(fruit_data)

# %%
x.iloc[:,0]
# Out:
# 0      243
# 8      242
# 28     241
# 32     240
# 36     239
# 38     238
# 40     237
# 45     236
# 46     235
# 47     234
# 49     233
# 52     232
# 55     231
# 56     230
# 58     229
# 60     228
# 61     227
# 62     226
# 66     225
# 69     224
# 70     223
# 71     222
# 72     221
# 75     220
# 76     219
# 82     218
# 83     217
# 86     216
# 90     215
# 93     214
#       ...
# 745     28
# 752     27
# 758     26
# 759     25
# 760     24
# 766     23
# 781     22
# 782     21
# 784     20
# 789     19
# 793     18
# 799     17
# 806     16
# 814     15
# 822     14
# 825     13
# 830     12
# 831     11
# 845     10
# 848      9
# 852      8
# 856      7
# 867      6
# 871      5
# 883      4
# 884      3
# 887      2
# 889      1
# 911      0
# 915    244
# Name: AcquisitionID, Length: 245, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le1 = LabelEncoder()
x.iloc[:,1] = le1.fit_transform(x.iloc[:,1])

# %%
x.iloc[:,1]
# Out:
# 0      10
# 8       6
# 28      5
# 32      0
# 36      3
# 38      3
# 40      0
# 45     12
# 46     12
# 47     11
# 49      2
# 52      0
# 55      7
# 56      6
# 58     11
# 60     10
# 61      2
# 62      5
# 66      0
# 69      9
# 70      3
# 71      9
# 72      7
# 75      7
# 76      6
# 82     10
# 83      5
# 86      8
# 90      0
# 93      7
#        ..
# 745     5
# 752     3
# 758     7
# 759     8
# 760     8
# 766     0
# 781     7
# 782     7
# 784     7
# 789     7
# 793     7
# 799     6
# 806     1
# 814    12
# 822    12
# 825    12
# 830    10
# 831    10
# 845     5
# 848     3
# 852     3
# 856     8
# 867     0
# 871     0
# 883     6
# 884     6
# 887     6
# 889     1
# 911    10
# 915     7
# Name: AcquisitionMonth, Length: 245, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le3 = LabelEncoder()
x.iloc[:,3] = le3.fit_transform(x.iloc[:,3])

# %%
x.iloc[:,3]
# Out:
# 0       38
# 8       43
# 28     172
# 32      43
# 36      97
# 38     189
# 40      96
# 45     210
# 46     102
# 47     211
# 49      97
# 52     150
# 55     204
# 56      29
# 58      64
# 60      93
# 61      54
# 62     172
# 66      95
# 69      96
# 70     183
# 71     208
# 72      45
# 75      59
# 76      12
# 82      42
# 83     213
# 86      96
# 90      28
# 93      67
#       ...
# 745     13
# 752    117
# 758     34
# 759    200
# 760     83
# 766     56
# 781    114
# 782    124
# 784    155
# 789     85
# 793    123
# 799    108
# 806     81
# 814    184
# 822     65
# 825     16
# 830    194
# 831    131
# 845    121
# 848    182
# 852    181
# 856     99
# 867     30
# 871      4
# 883     44
# 884     37
# 887     33
# 889     82
# 911    129
# 915    190
# Name: Business, Length: 245, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le4 = LabelEncoder()
x.iloc[:,4] = le4.fit_transform(x.iloc[:,4])

# %%
x.iloc[:,4]
# Out:
# 0      19
# 8      19
# 28     19
# 32     19
# 36     19
# 38     19
# 40     19
# 45     19
# 46     19
# 47     19
# 49     19
# 52     19
# 55     19
# 56     19
# 58     19
# 60     19
# 61     19
# 62     17
# 66     19
# 69     19
# 70     17
# 71     19
# 72     19
# 75     19
# 76     14
# 82     19
# 83     19
# 86     19
# 90     19
# 93     19
#        ..
# 745    17
# 752    19
# 758    10
# 759    19
# 760    17
# 766    19
# 781    19
# 782    19
# 784    19
# 789    19
# 793    19
# 799    19
# 806    19
# 814    16
# 822     9
# 825     1
# 830    14
# 831    19
# 845    17
# 848    19
# 852    10
# 856    19
# 867    10
# 871    19
# 883    10
# 884    10
# 887    19
# 889    19
# 911    19
# 915    19
# Name: Country, Length: 245, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le5 = LabelEncoder()
x.iloc[:,5] = le5.fit_transform(x.iloc[:,5])

# %%
x.iloc[:,5]
# Out:
# 0       94
# 8       16
# 28      66
# 32      17
# 36      22
# 38      98
# 40      99
# 45       2
# 46      58
# 47      54
# 49     108
# 52      34
# 55      37
# 56      23
# 58      29
# 60      81
# 61      10
# 62       5
# 66     145
# 69      65
# 70      80
# 71     143
# 72      50
# 75      41
# 76      63
# 82      19
# 83     129
# 86      53
# 90     120
# 93      12
#       ...
# 745    111
# 752    151
# 758     38
# 759    135
# 760     22
# 766     67
# 781     56
# 782     38
# 784    108
# 789    109
# 793     30
# 799     77
# 806    139
# 814    123
# 822     19
# 825     30
# 830    137
# 831    112
# 845     38
# 848     56
# 852     77
# 856     56
# 867     22
# 871    105
# 883     42
# 884     87
# 887     71
# 889    122
# 911    127
# 915    148
# Name: Value (USD), Length: 245, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
ley0 = LabelEncoder()
y.iloc[:,0] = ley0.fit_transform(y.iloc[:,0])

# %%
y.iloc[:,0]
# Out:
# 0      2
# 8      4
# 28     4
# 32     4
# 36     4
# 38     0
# 40     4
# 45     6
# 46     0
# 47     6
# 49     4
# 52     4
# 55     6
# 56     6
# 58     6
# 60     4
# 61     6
# 62     0
# 66     6
# 69     6
# 70     4
# 71     6
# 72     6
# 75     4
# 76     4
# 82     0
# 83     4
# 86     4
# 90     4
# 93     6
#       ..
# 745    2
# 752    1
# 758    4
# 759    1
# 760    1
# 766    5
# 781    5
# 782    5
# 784    2
# 789    2
# 793    0
# 799    6
# 806    0
# 814    2
# 822    6
# 825    0
# 830    4
# 831    6
# 845    0
# 848    4
# 852    4
# 856    5
# 867    0
# 871    5
# 883    1
# 884    4
# 887    6
# 889    3
# 911    3
# 915    4
# Name: ParentCompany, Length: 245, dtype: int64

# %%
y=y.astype('int')

# %%
from sklearn.model_selection import train_test_split                                                                                                                    
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size = 0.3 , random_state = 0)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier= DecisionTreeClassifier(random_state=0)
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
#x.iloc[:,0]=le.inverse_transform(x.iloc[:,0])

# %%
x_test
# Out:
#      AcquisitionID  AcquisitionMonth  AcquisitionYear  Business  Country  \
# 318            151                 0             2007        87       15
# 871              5                 0             2015         4       19
# 212            170                 9             2005        31        3
# 142            188                 2             2002       134       19
# 610             62                 1             2012        86       19
# 649             54                 8             2013        90       19
# 456            106                 9             2010       192       19
# 455            107                 9             2010        92       19
# 375            136                 8             2008       153       19
# 169            179                 0             2004        18        9
# 667             49                 7             2013        35       19
# 415            120                 1             2009       170       19
# ...

# %%
x_train.iloc[:,0]=le0.inverse_transform(x_train.iloc[:,0])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
x_train.iloc[:,0]
# Out:
# 379    ACQ581
# 158    ACQ780
# 400    ACQ562
# 135    ACQ800
# 183    ACQ758
# 83     ACQ848
# 708    ACQ285
# 577    ACQ402
# 759    ACQ239
# 113    ACQ820
# 56     ACQ872
# 32     ACQ894
# 344    ACQ612
# 76     ACQ854
# 95     ACQ837
# 760    ACQ238
# 155    ACQ783
# 143    ACQ794
# 626    ACQ359
# 395    ACQ567
# 69     ACQ860
# 653    ACQ334
# 434    ACQ531
# 138    ACQ799
# 673    ACQ316
# 257    ACQ691
# 130    ACQ805
# 416    ACQ548
# 558     ACQ42
# 781    ACQ219
#         ...
# 390    ACQ571
# 489    ACQ482
# 867    ACQ141
# 210    ACQ733
# 240    ACQ706
# 82     ACQ849
# 549    ACQ428
# 259     ACQ69
# 825     ACQ18
# 583    ACQ398
# 845    ACQ161
# 111    ACQ822
# 663    ACQ325
# 149    ACQ789
# 468    ACQ500
# 304    ACQ649
# 752    ACQ245
# 202    ACQ740
# 301    ACQ651
# 108    ACQ825
# 71     ACQ859
# 737    ACQ259
# 47     ACQ880
# 349    ACQ608
# 668    ACQ320
# 192     ACQ75
# 655    ACQ332
# 396    ACQ566
# 122    ACQ812
# 575    ACQ404
# ...

# %%
x_train.iloc[:,1]=le1.inverse_transform(x_train.iloc[:,1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
x_train.iloc[:,1]
# Out:
# 379        April
# 158       August
# 400    September
# 135    September
# 183    September
# 83       January
# 708      October
# 577     February
# 759        March
# 113         July
# 56          July
# 32         April
# 344    September
# 76          July
# 95        August
# 760        March
# 155         June
# 143     December
# 626     November
# 395         July
# 69           May
# 653        April
# 434     February
# 138      October
# 673         July
# 257     Feburary
# 130         July
# 416       August
# 558     December
# 781         June
#          ...
# 390         June
# 489    September
# 867        April
# 210          May
# 240     December
# 82      November
# 549    September
# 259         June
# 825    September
# 583        April
# 845      January
# 111         June
# 663          May
# 149        April
# 468         July
# 304     December
# 752     February
# 202        March
# 301     December
# 108          May
# 71           May
# ...

# %%
x_train.iloc[:,3]=le3.inverse_transform(x_train.iloc[:,3])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
x_train.iloc[:,3]
# Out:
# 379                             Mobile Internet software
# 158                                             Software
# 400                       Search and e-commerce services
# 135                             Software and video games
# 183                                         Audio player
# 83                            Wholesale drawing software
# 708                         DroidBooster App for Android
# 577                                    App search engine
# 759                           Virtual reality technology
# 113                                    Database Software
# 56                                  Calendaring software
# 32                                     Computer software
# 344                                  Advertising network
# 76                                  Application software
# 95                               Electronic mailing list
# 760                                   High-altitude UAVs
# ...

# %%
x_train.iloc[:,4]=le4.inverse_transform(x_train.iloc[:,4])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
x_train.iloc[:,4]
# Out:
# 379    USA
# 158    USA
# 400    USA
# 135     UK
# 183    USA
# 83     USA
# 708    FRA
# 577    USA
# 759    USA
# 113    USA
# 56     USA
# 32     USA
# 344    USA
# 76     SWE
# 95     USA
# 760     UK
# 155    USA
# 143    USA
# 626    CAN
# 395    FRA
# 69     USA
# 653    USA
# 434    USA
# 138    USA
# 673    USA
# 257    USA
# 130    DEN
# 416    JOR
# 558    USA
# 781    USA
#       ...
# 390    USA
# 489    SWE
# 867    ISR
# 210    USA
# 240    USA
# 82     USA
# 549    USA
# 259     UK
# 825    CAN
# 583    USA
# 845     UK
# 111    USA
# 663    USA
# 149    USA
# 468    USA
# 304    CHE
# 752    USA
# 202    CAN
# 301    TWN
# 108    CAN
# 71     USA
# 737    USA
# 47     USA
# 349    USA
# 668    ISR
# 192    USA
# 655    USA
# 396    USA
# 122    USA
# 575    ISR
# Name: Country, Length: 171, dtype: object

# %%
x_train.iloc[:,5]=le5.inverse_transform(x_train.iloc[:,5])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
x_train.iloc[:,5]
# Out:
# 379    5.000000e+08
# 158    4.500000e+05
# 400    4.860000e+08
# 135    3.750000e+08
# 183    1.600000e+08
# 83     1.375000e+09
# 708    2.300000e+07
# 577    5.000000e+07
# 759    2.000000e+09
# 113    1.000000e+09
# 56     2.100000e+07
# 32     1.415000e+07
# 344    3.000000e+08
# 76     1.254200e+08
# 95     4.320000e+08
# 760    2.000000e+07
# 155    1.630000e+09
# 143    2.350000e+08
# 626    1.700000e+07
# 395    3.400000e+08
# 69     1.300000e+08
# 653    3.000000e+07
# 434    5.000000e+07
# 138    3.500000e+09
# 673    5.000000e+07
# 257    8.650000e+08
# 130    1.330000e+09
# 416    1.670000e+08
# 558    2.620000e+10
# 781    1.000000e+08
#            ...
# 390    3.100000e+07
# 489    2.900000e+07
# 867    2.000000e+07
# 210    7.000000e+06
# 240    2.000000e+07
# 82     1.500000e+07
# 549    1.510000e+08
# 259    1.500000e+08
# 825    3.000000e+07
# 583    1.000000e+09
# 845    5.000000e+07
# 111    1.200000e+07
# 663    1.100000e+09
# 149    1.020000e+08
# ...

# %%
y_train.iloc[:,-1:]=ley0.inverse_transform(y_train.iloc[:,-1:])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
y_train.iloc[:,-1:]
# Out:
#     ParentCompany
# 379     Microsoft
# 158     Microsoft
# 400     Microsoft
# 135     Microsoft
# 183         Yahoo
# 83      Microsoft
# 708        Google
# 577         Apple
# 759      Facebook
# 113           IBM
# 56          Yahoo
# 32      Microsoft
# 344         Yahoo
# 76      Microsoft
# 95          Yahoo
# 760      Facebook
# 155         Yahoo
# 143         Yahoo
# 626        Google
# 395           IBM
# 69          Yahoo
# 653        Google
# 434        Google
# 138           IBM
# 673         Yahoo
# 257           IBM
# 130     Microsoft
# 416         Yahoo
# 558     Microsoft
# 781       Twitter
# ..            ...
# 390      Facebook
# 489         Apple
# 867         Apple
# 210     Microsoft
# 240         Yahoo
# 82          Apple
# 549        Google
# 259       Twitter
# 825         Apple
# 583      Facebook
# 845         Apple
# 111         Yahoo
# 663         Yahoo
# 149        Google
# 468      Facebook
# 304        Google
# 752      Facebook
# 202         Yahoo
# ...

# %%
x_test
# Out:
#      AcquisitionID  AcquisitionMonth  AcquisitionYear  Business  Country  \
# 318            151                 0             2007        87       15
# 871              5                 0             2015         4       19
# 212            170                 9             2005        31        3
# 142            188                 2             2002       134       19
# 610             62                 1             2012        86       19
# 649             54                 8             2013        90       19
# 456            106                 9             2010       192       19
# 455            107                 9             2010        92       19
# 375            136                 8             2008       153       19
# 169            179                 0             2004        18        9
# 667             49                 7             2013        35       19
# 415            120                 1             2009       170       19
# ...

# %%
x_test.iloc[:,0]=le0.inverse_transform(x_test.iloc[:,0])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
x_test.iloc[:,0]
# Out:
# 318    ACQ636
# 871    ACQ138
# 212    ACQ731
# 142    ACQ795
# 610    ACQ373
# 649    ACQ338
# 456    ACQ511
# 455    ACQ512
# 375    ACQ585
# 169    ACQ770
# 667    ACQ321
# 415    ACQ549
# 308    ACQ645
# 831    ACQ174
# 688    ACQ302
# 507    ACQ466
# 616    ACQ368
# 598    ACQ384
# 224    ACQ720
# 361    ACQ598
# 380    ACQ580
# 120    ACQ814
# 167    ACQ772
# 650    ACQ337
# 420    ACQ544
# 605    ACQ378
# 431    ACQ534
# 46     ACQ881
# 784    ACQ216
# 333    ACQ622
#         ...
# 208    ACQ735
# 479    ACQ491
# 377    ACQ583
# 66     ACQ863
# 378    ACQ582
# 60     ACQ869
# 521    ACQ453
# 45     ACQ882
# 524    ACQ450
# 714     ACQ28
# 501    ACQ471
# 520    ACQ454
# 369    ACQ590
# 413    ACQ550
# 290    ACQ661
# 102    ACQ830
# 464    ACQ504
# 541    ACQ435
# 334    ACQ621
# 915    AcQ916
# 315    ACQ639
# 766    ACQ232
# 852    ACQ155
# 712    ACQ281
# 793    ACQ208
# 61     ACQ868
# 550    ACQ427
# 565    ACQ413
# 239    ACQ707
# 36     ACQ890
# ...

# %%
x_test.iloc[:,1]=le1.inverse_transform(x_test.iloc[:,1])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
x_test.iloc[:,1]
# Out:
# 318        April
# 871        April
# 212          May
# 142     December
# 610       August
# 649        March
# 456          May
# 455          May
# 375        March
# 169        April
# 667         June
# 415       August
# 308     February
# 831     November
# 688       August
# 507      January
# 616      October
# 598         June
# 224       August
# 361      January
# 380        April
# 120     February
# 167        March
# 650        March
# 420     November
# 605         July
# 431      January
# 46     September
# 784         June
# 333         June
#          ...
# 208        April
# 479       August
# 377        April
# 66         April
# 378        April
# 60      November
# 521        April
# 45     September
# 524          May
# 714          May
# 501     November
# 520        April
# 369     February
# 413       August
# 290      October
# 102     February
# 464         June
# 541       August
# 334         July
# 915         June
# 315        April
# ...

# %%
x_test.iloc[:,3]=le3.inverse_transform(x_test.iloc[:,3])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
x_test.iloc[:,3]
# Out:
# 318                                  IT Services
# 871                                  Advertising
# 212                               Certain assets
# 142                   Online enterprise location
# 610                      Human Capital Solutions
# 649                              Indoor location
# 456                  Video and audio compression
# 455                Intellectual property/patents
# 375                    Rootkit security software
# 169                                 BPO Services
# 667               Cloud Computing Infrastructure
# 415                 Social networking aggregator
# 308                          In-game advertising
# 831                     Online Video Advertising
# 688                               Cyber Security
# 507                                  Daily deals
# 616                           Facial recognition
# 598                    Face recognition platform
# 224                      Mobile operating system
# ...

# %%
x_test.iloc[:,4]=le4.inverse_transform(x_test.iloc[:,4])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
x_test.iloc[:,4]
# Out:
# 318    SWI
# 871    USA
# 212    CHN
# 142    USA
# 610    USA
# 649    USA
# 456    USA
# 455    USA
# 375    USA
# 169    IND
# 667    USA
# 415    USA
# 308    USA
# 831    USA
# 688    ISR
# 507    AUS
# 616    UKR
# 598    ISR
# 224    USA
# 361    ISR
# 380    USA
# 120    USA
# 167     EU
# 650     UK
# 420    USA
# 605    USA
# 431    USA
# 46     USA
# 784    USA
# 333    USA
#       ...
# 208    USA
# 479    USA
# 377    SWE
# 66     USA
# 378    USA
# 60     USA
# 521    USA
# 45     USA
# 524    LUX
# 714    USA
# 501    USA
# 520    USA
# 369    USA
# 413    USA
# 290    USA
# 102    AUS
# 464    USA
# 541    SWE
# 334    USA
# 915    USA
# 315    USA
# 766    USA
# 852    ISR
# 712    ISR
# 793    USA
# 61     USA
# 550    GER
# 565    USA
# 239    AUS
# 36     USA
# Name: Country, Length: 74, dtype: object

# %%
x_test.iloc[:,5]=le5.inverse_transform(x_test.iloc[:,5])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
x_test.iloc[:,5]
# Out:
# 318    4.600000e+08
# 871    4.790000e+08
# 212    1.500000e+07
# 142    9.584900e+07
# 610    1.400000e+09
# 649    2.000000e+07
# 456    6.820000e+07
# 455    4.000000e+07
# 375    5.000000e+06
# 169    1.700000e+08
# 667    2.000000e+09
# 415    4.750000e+07
# 308    2.300000e+07
# 831    6.400000e+08
# 688    1.000000e+09
# 507    4.000000e+07
# 616    4.500000e+07
# 598    1.000000e+08
# 224    5.000000e+07
# 361    3.000000e+08
# 380    2.000000e+08
# 120    4.360000e+08
# 167    5.790000e+08
# 650    3.000000e+07
# 420    3.000000e+07
# 605    3.560000e+08
# 431    2.750000e+08
# 46     1.100000e+08
# 784    5.000000e+08
# 333    2.000000e+08
#            ...
# 208    1.100000e+09
# 479    4.800000e+08
# 377    8.450000e+08
# 66     5.700000e+09
# 378    7.500000e+07
# 60     2.650000e+08
# 521    2.000000e+07
# 45     1.400000e+06
# 524    8.500000e+09
# 714    2.000000e+08
# 501    8.500000e+06
# 520    6.760000e+08
# 369    1.600000e+08
# 413    1.330000e+08
# ...

# %%
y_test.iloc[:,-1:]=ley0.inverse_transform(y_test.iloc[:,-1:])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
y_test.iloc[:,-1:]
# Out:
#     ParentCompany
# 318           IBM
# 871       Twitter
# 212     Microsoft
# 142     Microsoft
# 610           IBM
# 649         Apple
# 456        Google
# 455      Facebook
# 375     Microsoft
# 169           IBM
# 667           IBM
# 415      Facebook
# 308        Google
# 831         Yahoo
# 688           IBM
# 507         Yahoo
# 616        Google
# 598      Facebook
# 224        Google
# 361           IBM
# 380           IBM
# 120         Yahoo
# 167         Yahoo
# 650         Yahoo
# 420        Google
# 605         Apple
# 431         Apple
# 46          Apple
# 784        Google
# 333     Microsoft
# ..            ...
# 208           IBM
# 479           IBM
# 377           IBM
# 66          Yahoo
# 378     Microsoft
# 60      Microsoft
# 521         Yahoo
# 45          Yahoo
# 524     Microsoft
# 714         Apple
# 501      Facebook
# 520        Google
# 369         Yahoo
# 413        Google
# 290        Google
# 102         Yahoo
# 464        Google
# 541         Apple
# ...

# %%
new=LabelEncoder().fit_transform(['ACQ636','April',2015,'IT Services','SWI','4.600000e+08'])

# %%
new
# Out:
# array([2, 3, 0, 4, 5, 1], dtype=int64)

# %%
pd.DataFrame(new)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  0

# %%
y_predict =classifier.predict([new])

# %%
y_predict=pd.DataFrame(y_predict)

# %%
y_test
# Out:
#     ParentCompany
# 318           IBM
# 871       Twitter
# 212     Microsoft
# 142     Microsoft
# 610           IBM
# 649         Apple
# 456        Google
# 455      Facebook
# 375     Microsoft
# 169           IBM
# 667           IBM
# 415      Facebook
# 308        Google
# 831         Yahoo
# 688           IBM
# 507         Yahoo
# 616        Google
# 598      Facebook
# 224        Google
# 361           IBM
# 380           IBM
# 120         Yahoo
# 167         Yahoo
# 650         Yahoo
# 420        Google
# 605         Apple
# 431         Apple
# 46          Apple
# 784        Google
# 333     Microsoft
# ..            ...
# 208           IBM
# 479           IBM
# 377           IBM
# 66          Yahoo
# 378     Microsoft
# 60      Microsoft
# 521         Yahoo
# 45          Yahoo
# 524     Microsoft
# 714         Apple
# 501      Facebook
# 520        Google
# 369         Yahoo
# 413        Google
# 290        Google
# 102         Yahoo
# 464        Google
# 541         Apple
# ...

# %%
y_predict.shape
# Out:
# (1, 1)

# %%
x_test_pred=LabelEncoder().fit_transform(x_test.iloc[:,3])

# %%
x_test_pred=pd.DataFrame(x_test_pred)

# %%
x_test_pred
# Out:
#      0
# 0   23
# 1    2
# 2    7
# 3   46
# 4   22
# 5   25
# 6   63
# 7   26
# 8   51
# 9    5
# 10   8
# 11  55
# 12  24
# 13  43
# 14  12
# 15  13
# 16  21
# 17  20
# 18  38
# 19  19
# 20  14
# 21  31
# 22  49
# 23  41
# 24  67
# 25  48
# 26  37
# 27  33
# 28  52
# 29  40
# ..  ..
# 44  17
# 45  34
# 46  18
# 47  29
# 48  47
# 49  27
# 50  50
# 51  69
# 52  59
# 53   4
# 54   3
# 55  60
# 56  65
# 57  64
# 58  66
# 59  45
# 60   2
# 61   0
# 62  67
# 63  62
# 64  44
# 65  16
# 66  58
# 67  57
# 68  39
# 69  15
# 70  42
# 71   9
# 72  35
# 73  30
#
# [74 rows x 1 columns]

# %%
pred_y=classifier.predict((x_test_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-88d50fa2baa8> in <module>()
# ----> 1 pred_y=classifier.predict((x_test_pred))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\tree.py in predict(self, X, check_input)
#     410         """
#     411         check_is_fitted(self, 'tree_')
# --> 412         X = self._validate_X_predict(X, check_input)
#     413         proba = self.tree_.predict(X)
#     414         n_samples = X.shape[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\tree.py in _validate_X_predict(self, X, check_input)
#     382                              "match the input. Model n_features is %s and "
#     383                              "input n_features is %s "
# --> 384                              % (self.n_features_, n_features))
#     385
#     386         return X
#
# ...

# %%
y_test
# Out:
#     ParentCompany
# 318           IBM
# 871       Twitter
# 212     Microsoft
# 142     Microsoft
# 610           IBM
# 649         Apple
# 456        Google
# 455      Facebook
# 375     Microsoft
# 169           IBM
# 667           IBM
# 415      Facebook
# 308        Google
# 831         Yahoo
# 688           IBM
# 507         Yahoo
# 616        Google
# 598      Facebook
# 224        Google
# 361           IBM
# 380           IBM
# 120         Yahoo
# 167         Yahoo
# 650         Yahoo
# 420        Google
# 605         Apple
# 431         Apple
# 46          Apple
# 784        Google
# 333     Microsoft
# ..            ...
# 208           IBM
# 479           IBM
# 377           IBM
# 66          Yahoo
# 378     Microsoft
# 60      Microsoft
# 521         Yahoo
# 45          Yahoo
# 524     Microsoft
# 714         Apple
# 501      Facebook
# 520        Google
# 369         Yahoo
# 413        Google
# 290        Google
# 102         Yahoo
# 464        Google
# 541         Apple
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,classifier.predict(([x_test_pred])))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-2062c998c0a2> in <module>()
#       1 from sklearn.metrics import accuracy_score
# ----> 2 accuracy_score(y_test,classifier.predict(([x_test_pred])))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\tree.py in predict(self, X, check_input)
#     410         """
#     411         check_is_fitted(self, 'tree_')
# --> 412         X = self._validate_X_predict(X, check_input)
#     413         proba = self.tree_.predict(X)
#     414         n_samples = X.shape[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\tree.py in _validate_X_predict(self, X, check_input)
#     382                              "match the input. Model n_features is %s and "
#     383                              "input n_features is %s "
# --> 384                              % (self.n_features_, n_features))
#     385
# ...
